# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.path import Path

# -----------------------------
# Charger le fichier NetCDF
# -----------------------------
file_path = "/data/users/maxb/PREPROC/preproc_CROSCIM_x50.nc"
ds = xr.open_dataset(file_path)

# Choisir un sample (ici sample=0)
sample_idx = 0
cristal = ds["cristal_SIT"].isel(record=sample_idx, sample=0)
cimr    = ds["cimr_SIT"].isel(record=sample_idx, sample=0)
lat = ds["lat"].isel(record=0, sample=0)
lon = ds["lon"].isel(record=0,sample=0)

# -----------------------------
# Moyenne sur le temps
# -----------------------------
cristal_mean = cristal.mean(dim='time', skipna=True)
cimr_mean    = cimr.mean(dim='time', skipna=True)

# Convertir en numpy
lon_np = lon.values
lat_np = lat.values
cristal_np = cristal_mean.values
cimr_np    = cimr_mean.values

# -----------------------------
# Circular boundary
# -----------------------------
theta = np.linspace(0, 2*np.pi, 200)
center = [0.5, 0.5]
radius = 0.5
verts = np.vstack([np.sin(theta)*radius + center[0],
                   np.cos(theta)*radius + center[1]]).T
circle_path = Path(verts)

# -----------------------------
# Figure et projection
# -----------------------------
fig = plt.figure(figsize=(12,6))
proj = ccrs.NorthPolarStereo()

# -----------------------------
# Cristal SIT
# -----------------------------
ax1 = plt.subplot(1, 2, 1, projection=proj)
ax1.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax1.coastlines()
ax1.add_feature(cfeature.LAND, facecolor='gray')
ax1.set_facecolor('lightgray')
ax1.set_boundary(circle_path, transform=ax1.transAxes)

mask1 = np.isfinite(cristal_np)
sc1 = ax1.scatter(
    lon_np[mask1], lat_np[mask1],
    c=cristal_np[mask1],
    s=10, cmap='viridis',
    transform=ccrs.PlateCarree()
)
plt.colorbar(sc1, ax=ax1, orientation='horizontal', pad=0.05, shrink=0.8, location='top')
ax1.set_title("cristal_SIT (mean over time)")

# -----------------------------
# CIMR SIT
# -----------------------------
ax2 = plt.subplot(1, 2, 2, projection=proj)
ax2.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax2.coastlines()
ax2.add_feature(cfeature.LAND, facecolor='gray')
ax2.set_facecolor('lightgray')
ax2.set_boundary(circle_path, transform=ax2.transAxes)

mask2 = np.isfinite(cimr_np)
sc2 = ax2.scatter(
    lon_np[mask2], lat_np[mask2],
    c=cimr_np[mask2],
    s=10, cmap='viridis',
    transform=ccrs.PlateCarree()
)
plt.colorbar(sc2, ax=ax2, orientation='horizontal', pad=0.05, shrink=0.8, location='top')
ax2.set_title("cimr_SIT (mean over time)")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 80
#      73 #ax2.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
#      74 #ax2.coastlines()
#      75 #ax2.add_feature(cfeature.LAND, facecolor='gray')
#      76 #ax2.set_facecolor('lightgray')
#      77 #ax2.set_boundary(circle_path, transform=ax2.transAxes)
#      79 mask2 = np.isfinite(cimr_np)
# ---> 80 sc2 = ax2.scatter(
#      81     lon_np[mask2], lat_np[mask2],
#      82     c=cimr_np[mask2],
#      83     s=10, cmap='viridis',
#      84     transform=ccrs.PlateCarree()
#      85 )
#      86 plt.colorbar(sc2, ax=ax2, orientation='horizontal', pad=0.05, shrink=0.8, location='top')
#      87 ax2.set_title("cimr_SIT (mean over time)")
#
# ...
